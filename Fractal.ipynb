# %% [markdown]
# # Фрактал Ньютона x**3=1

# %%
import math
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
def f(x):
    return x**3-1

# %%
def d(x):
    return 3*x**2

# %%
def iter(x):
    for i in range(n):
        x -= f(x)/d(x)
    return x

# %%
def graph(x,y):
    x_g, y_g, x_y, y_y, x_r, y_r = [], [], [], [], [], []
    for xi in x:
        for yi in y:
            k = iter(xi + yi*1j).imag
            if k <= -0.866:
                x_g.append(xi)
                y_g.append(yi)
            elif k >= 0.866:
                x_y.append(xi)
                y_y.append(yi)
            else:
                x_r.append(xi)
                y_r.append(yi)
    
    plt.figure(figsize=(15,10))
    plt.plot(x_g, y_g, 'g,')
    plt.plot(x_y, y_y, 'y,')
    plt.plot(x_r, y_r, 'r,')
    plt.show()

# %%
n = 50
x=np.arange(-2,2,0.004)
y=np.arange(-2,2,0.004)

# %%
graph(x,y)
